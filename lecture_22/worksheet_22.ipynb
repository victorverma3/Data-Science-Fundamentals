# %% [markdown]
# # Worksheet 22
#
# Name: Victor Verma UID: U86967149
#
# ### Topics
#
# -   Neural Networks
#
# ## Neural Networks
#
# Nothing to do in this worksheet except follow along in lecture / use this code
# to better understand Neural Networks.

# %%
import math as m
import numpy as np
import matplotlib.pyplot as plt
import sklearn.datasets as datasets
from tensorflow import keras, math, random, stack
from tensorflow.keras import layers, initializers
from tensorflow.keras.activations import relu

#       x[0] --- h1
#            \ /    \
#             X       output
#            / \    /
#       x[1] --- h2
#
# This is the base model - nothing fancy here

# Set random seed for reproducibility
np.random.seed(1)
random.set_seed(1)

# Data generation - don't modify
centers = [[0, 0]]
t, _ = datasets.make_blobs(
    n_samples=200, centers=centers, cluster_std=1, random_state=1
)

colors = np.array([x for x in "bgrcmyk"])
colors = np.hstack([colors] * 20)


# CIRCLE
def generate_circle_data(t):
    # create some space between the classes
    X = np.array(
        list(
            filter(
                lambda x: (x[0] - centers[0][0]) ** 2 + (x[1] - centers[0][1]) ** 2 < 1
                or (x[0] - centers[0][0]) ** 2 + (x[1] - centers[0][1]) ** 2 > 1.5,
                t,
            )
        )
    )
    Y = np.array(
        [
            1 if (x[0] - centers[0][0]) ** 2 + (x[1] - centers[0][1]) ** 2 >= 1 else 0
            for x in X
        ]
    )
    return X, Y


# LINE
def generate_line_data(t):
    # create some space between the classes
    X = np.array(list(filter(lambda x: x[0] - x[1] < -0.5 or x[0] - x[1] > 0.5, t)))
    Y = np.array([1 if x[0] - x[1] >= 0 else 0 for x in X])
    return X, Y


# CURVE
def generate_curve_data(t):
    # create some space between the classes
    X = np.array(
        list(
            filter(
                lambda x: m.cos(4 * x[0]) - x[1] < -0.5 or m.cos(4 * x[0]) - x[1] > 0.5,
                t,
            )
        )
    )
    Y = np.array([1 if m.cos(4 * x[0]) - x[1] >= 0 else 0 for x in X])
    return X, Y


# XOR
def generate_xor_data():
    X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
    Y = np.array([x[0] ^ x[1] for x in X])
    return X, Y


PLOT_HIDDEN_LAYER_2D = True
PLOT_HIDDEN_LAYER_3D = False

# The model - modify this
model = keras.models.Sequential()
model.add(layers.Dense(2, input_dim=2, activation="sigmoid"))
model.add(layers.Dense(1, activation="sigmoid"))
model.compile(loss="binary_crossentropy")

# X, Y = generate_circle_data(t)
# X, Y = generate_line_data(t)
# X, Y = generate_curve_data(t)
X, Y = generate_xor_data()

# plot the data
plt.scatter(X[:, 0], X[:, 1], color=colors[Y].tolist(), s=100, alpha=0.9)
plt.show()

history = model.fit(X, Y, batch_size=2, epochs=1000)

if PLOT_HIDDEN_LAYER_2D:
    # Show the transformation of the input at the first hidden layer
    layer = model.layers[0]
    print(layer.get_config(), layer.get_weights())
    keras_function = keras.backend.function([model.input], [layer.output])
    layerVals = np.array(keras_function(X))[0]
    plt.scatter(
        layerVals[:, 0], layerVals[:, 1], color=colors[Y].tolist(), s=100, alpha=0.9
    )
    plt.show()

    # create a mesh to plot in
    h = 0.02  # step size in the mesh
    x_min, x_max = layerVals[:, 0].min() - 0.5, layerVals[:, 0].max() + 1
    y_min, y_max = layerVals[:, 1].min() - 0.5, layerVals[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    meshData = np.c_[xx.ravel(), yy.ravel()]

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh
    fig, ax = plt.subplots()
    layer = model.layers[-1]

    intermediateModel = keras.models.Sequential()
    intermediateModel.add(layers.Dense(1, input_dim=2, activation="sigmoid"))
    intermediateModel.compile(loss="binary_crossentropy")
    intermediateModel.layers[0].set_weights(layer.get_weights())

    Z = intermediateModel.predict(meshData)
    Z = np.array([0 if x < 0.5 else 1 for x in Z])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.Paired)

    T = intermediateModel.predict(layerVals)
    T = np.array([0 if x < 0.5 else 1 for x in T])
    T = T.reshape(layerVals[:, 0].shape)
    ax.scatter(
        layerVals[:, 0], layerVals[:, 1], color=colors[T].tolist(), s=100, alpha=0.9
    )
    ax.set_xlabel("h0")
    ax.set_ylabel("h1")
    plt.show()

if PLOT_HIDDEN_LAYER_3D:
    # Show the transformation of the input at the first hidden layer
    layer = model.layers[0]
    print(layer.get_config(), layer.get_weights())
    keras_function = keras.backend.function([model.input], [layer.output])
    layerVals = np.array(keras_function(X))[0]
    fig = plt.figure()
    ax = fig.add_subplot(111, projection="3d")
    ax.scatter(
        layerVals[:, 0],
        layerVals[:, 1],
        layerVals[:, 2],
        color=colors[Y].tolist(),
        s=100,
        alpha=0.9,
    )
    plt.show()

    # create a mesh to plot in
    h = 0.1  # step size in the mesh
    x_min, x_max = layerVals[:, 0].min() - 0.5, layerVals[:, 0].max() + 1
    y_min, y_max = layerVals[:, 1].min() - 0.5, layerVals[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    meshData = np.c_[xx.ravel(), yy.ravel(), np.zeros(len(xx.ravel()))]

    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh
    fig, ax = plt.subplots()
    layer = model.layers[-1]

    intermediateModel = keras.models.Sequential()
    intermediateModel.add(layers.Dense(1, input_dim=3, activation="sigmoid"))
    intermediateModel.compile(loss="binary_crossentropy")
    intermediateModel.layers[0].set_weights(layer.get_weights())

    Z = intermediateModel.predict(meshData)
    Z = np.array([0 if x < 0.5 else 1 for x in Z])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.Paired)  # plot in 2D
    ax.axis("off")

    T = intermediateModel.predict(layerVals)
    T = np.array([0 if x < 0.5 else 1 for x in T])
    T = T.reshape(layerVals[:, 0].shape)
    ax.scatter(
        layerVals[:, 0], layerVals[:, 1], color=colors[T].tolist(), s=100, alpha=0.9
    )  # plot in 2D
    plt.show()

# Plot the decision boundary

# create a mesh to plot in
h = 0.02  # step size in the mesh
x_min, x_max = X[:, 0].min() - 0.5, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 0.5, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
meshData = np.c_[xx.ravel(), yy.ravel()]

fig, ax = plt.subplots()
Z = model.predict(meshData)
Z = np.array([0 if x < 0.5 else 1 for x in Z])
Z = Z.reshape(xx.shape)
ax.contourf(xx, yy, Z, alpha=0.3, cmap=plt.cm.Paired)
ax.axis("off")

# Plot also the training points
T = model.predict(X)
T = np.array([0 if x < 0.5 else 1 for x in T])
T = T.reshape(X[:, 0].shape)
ax.scatter(X[:, 0], X[:, 1], color=colors[T].tolist(), s=100, alpha=0.9)
plt.title("Decision Boundary")
plt.show()
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 1s 12ms/step - loss: 0.7701
# Epoch 2/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7679
# Epoch 3/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7663
# Epoch 4/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7650
# Epoch 5/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7657
# Epoch 6/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7636
# Epoch 7/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7639
# Epoch 8/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7633
# Epoch 9/1000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7620
# Epoch 10/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7615
# Epoch 11/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7618
# Epoch 12/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7606
# Epoch 13/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7601
# Epoch 14/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7596
# Epoch 15/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7590
# Epoch 16/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7594
# Epoch 17/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7580
# Epoch 18/1000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7575
# Epoch 19/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7580
# Epoch 20/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7566
# Epoch 21/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7562
# Epoch 22/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7557
# Epoch 23/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7551
# Epoch 24/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7546
# Epoch 25/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7540
# Epoch 26/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7534
# Epoch 27/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7528
# Epoch 28/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7535
# Epoch 29/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7519
# Epoch 30/1000
# 2/2 [==============================] - 0s 90ms/step - loss: 0.7514
# Epoch 31/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7520
# Epoch 32/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7515
# Epoch 33/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7502
# Epoch 34/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7506
# Epoch 35/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7495
# Epoch 36/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7491
# Epoch 37/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7487
# Epoch 38/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7483
# Epoch 39/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7489
# Epoch 40/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7475
# Epoch 41/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7471
# Epoch 42/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7477
# Epoch 43/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7472
# Epoch 44/1000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7468
# Epoch 45/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7465
# Epoch 46/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7455
# Epoch 47/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7452
# Epoch 48/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7457
# Epoch 49/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7453
# Epoch 50/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7450
# Epoch 51/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7441
# Epoch 52/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7438
# Epoch 53/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7434
# Epoch 54/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7439
# Epoch 55/1000
# 2/2 [==============================] - 0s 62ms/step - loss: 0.7436
# Epoch 56/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7425
# Epoch 57/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7429
# Epoch 58/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7426
# Epoch 59/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7417
# Epoch 60/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7421
# Epoch 61/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7411
# Epoch 62/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7415
# Epoch 63/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7412
# Epoch 64/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7410
# Epoch 65/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7400
# Epoch 66/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7405
# Epoch 67/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7402
# Epoch 68/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7393
# Epoch 69/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7390
# Epoch 70/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7387
# Epoch 71/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7393
# Epoch 72/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7389
# Epoch 73/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7379
# Epoch 74/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7376
# Epoch 75/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7381
# Epoch 76/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7371
# Epoch 77/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7368
# Epoch 78/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7365
# Epoch 79/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7370
# Epoch 80/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7366
# Epoch 81/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7356
# Epoch 82/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7353
# Epoch 83/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.7358
# Epoch 84/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7347
# Epoch 85/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7353
# Epoch 86/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7349
# Epoch 87/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7340
# Epoch 88/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7337
# Epoch 89/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7343
# Epoch 90/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7332
# Epoch 91/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.7338
# Epoch 92/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7335
# Epoch 93/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7325
# Epoch 94/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7323
# Epoch 95/1000
# 2/2 [==============================] - 0s 14ms/step - loss: 0.7328
# Epoch 96/1000
# 2/2 [==============================] - 0s 18ms/step - loss: 0.7318
# Epoch 97/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7315
# Epoch 98/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7313
# Epoch 99/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7310
# Epoch 100/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7317
# Epoch 101/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7312
# Epoch 102/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7302
# Epoch 103/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7300
# Epoch 104/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7297
# Epoch 105/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7294
# Epoch 106/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7291
# Epoch 107/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7288
# Epoch 108/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7284
# Epoch 109/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7280
# Epoch 110/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7276
# Epoch 111/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7286
# Epoch 112/1000
# 2/2 [==============================] - 0s 67ms/step - loss: 0.7271
# Epoch 113/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7277
# Epoch 114/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7266
# Epoch 115/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7263
# Epoch 116/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7260
# Epoch 117/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7267
# Epoch 118/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7255
# Epoch 119/1000
# 2/2 [==============================] - 0s 12ms/step - loss: 0.7261
# Epoch 120/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7250
# Epoch 121/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.
1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7062
# Epoch 245/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7069
# Epoch 246/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7060
# Epoch 247/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7059
# Epoch 248/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7067
# Epoch 249/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7066
# Epoch 250/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7057
# Epoch 251/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7056
# Epoch 252/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7055
# Epoch 253/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7054
# Epoch 254/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7053
# Epoch 255/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7052
# Epoch 256/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.7051
# Epoch 257/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7049
# Epoch 258/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7048
# Epoch 259/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7047
# Epoch 260/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7059
# Epoch 261/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7054
# Epoch 262/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7052
# Epoch 263/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7051
# Epoch 264/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7043
# Epoch 265/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7050
# Epoch 266/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7041
# Epoch 267/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7041
# Epoch 268/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7040
# Epoch 269/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7048
# Epoch 270/1000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7046
# Epoch 271/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7038
# Epoch 272/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7037
# Epoch 273/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7037
# Epoch 274/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7036
# Epoch 275/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7035
# Epoch 276/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7034
# Epoch 277/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7044
# Epoch 278/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7033
# Epoch 279/1000
# 2/2 [==============================] - 0s 21ms/step - loss: 0.7032
# Epoch 280/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7031
# Epoch 281/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7030
# Epoch 282/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7029
# Epoch 283/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7039
# Epoch 284/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7027
# Epoch 285/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7026
# Epoch 286/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7025
# Epoch 287/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7035
# Epoch 288/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7024
# Epoch 289/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7033
# Epoch 290/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7031
# Epoch 291/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7029
# Epoch 292/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7028
# Epoch 293/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7028
# Epoch 294/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7027
# Epoch 295/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7020
# Epoch 296/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7020
# Epoch 297/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7020
# Epoch 298/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7019
# Epoch 299/1000
# 2/2 [==============================] - 0s 22ms/step - loss: 0.7018
# Epoch 300/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7026
# Epoch 301/1000
# 2/2 [==============================] - 0s 51ms/step - loss: 0.7017
# Epoch 302/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7016
# Epoch 303/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7016
# Epoch 304/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7025
# Epoch 305/1000
# 2/2 [==============================] - 0s 13ms/step - loss: 0.7023
# Epoch 306/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7014
# Epoch 307/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7021
# Epoch 308/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7020
# Epoch 309/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7012
# Epoch 310/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7012
# Epoch 311/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7020
# Epoch 312/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7011
# Epoch 313/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7011
# Epoch 314/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7019
# Epoch 315/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7010
# Epoch 316/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7009
# Epoch 317/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7017
# Epoch 318/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7008
# Epoch 319/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7007
# Epoch 320/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7007
# Epoch 321/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7006
# Epoch 322/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7005
# Epoch 323/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7015
# Epoch 324/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7012
# Epoch 325/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7004
# Epoch 326/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7011
# Epoch 327/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7010
# Epoch 328/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7002
# Epoch 329/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7002
# Epoch 330/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7001
# Epoch 331/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7009
# Epoch 332/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7000
# Epoch 333/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7000
# Epoch 334/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6999
# Epoch 335/1000
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7008
# Epoch 336/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7006
# Epoch 337/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6998
# Epoch 338/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6998
# Epoch 339/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6997
# Epoch 340/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6997
# Epoch 341/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6996
# Epoch 342/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7005
# Epoch 343/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6995
# Epoch 344/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6994
# Epoch 345/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6994
# Epoch 346/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7004
# Epoch 347/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7001
# Epoch 348/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7000
# Epoch 349/1000
# 2/2 [==============================] - 0s 159ms/step - loss: 0.6992
# Epoch 350/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6992
# Epoch 351/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7000
# Epoch 352/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6991
# Epoch 353/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6991
# Epoch 354/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6999
# Epoch 355/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6998
# Epoch 356/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6990
# Epoch 357/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6989
# Epoch 358/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6989
# Epoch 359/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6989
# Epoch 360/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6997
# Epoch 361/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6996
# Epoch 362/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6987
# Epoch 363/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6987
# Epoch 364/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6987
# Epoch 365/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6986
# Epoch 366/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.
1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 843/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6942
# Epoch 844/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 845/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6942
# Epoch 846/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6934
# Epoch 847/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6942
# Epoch 848/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6934
# Epoch 849/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 850/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 851/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 852/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6943
# Epoch 853/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6942
# Epoch 854/1000
# 2/2 [==============================] - 0s 20ms/step - loss: 0.6941
# Epoch 855/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 856/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6941
# Epoch 857/1000
# 2/2 [==============================] - 0s 11ms/step - loss: 0.6934
# Epoch 858/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6934
# Epoch 859/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6942
# Epoch 860/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6934
# Epoch 861/1000
# 2/2 [==============================] - 0s 19ms/step - loss: 0.6934
# Epoch 862/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 863/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 864/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 865/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 866/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6944
# Epoch 867/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6942
# Epoch 868/1000
# 2/2 [==============================] - 0s 24ms/step - loss: 0.6934
# Epoch 869/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6934
# Epoch 870/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6934
# Epoch 871/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 872/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 873/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6944
# Epoch 874/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6942
# Epoch 875/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6934
# Epoch 876/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 877/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 878/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6934
# Epoch 879/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 880/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6944
# Epoch 881/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6942
# Epoch 882/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 883/1000
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6934
# Epoch 884/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6942
# Epoch 885/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6934
# Epoch 886/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 887/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6942
# Epoch 888/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 889/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6934
# Epoch 890/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 891/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6934
# Epoch 892/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 893/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 894/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 895/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6934
# Epoch 896/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 897/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6934
# Epoch 898/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6946
# Epoch 899/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6942
# Epoch 900/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 901/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6942
# Epoch 902/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 903/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6941
# Epoch 904/1000
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6940
# Epoch 905/1000
# 2/2 [==============================] - 0s 17ms/step - loss: 0.6933
# Epoch 906/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 907/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6933
# Epoch 908/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 909/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6942
# Epoch 910/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 911/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6941
# Epoch 912/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6940
# Epoch 913/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6933
# Epoch 914/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6940
# Epoch 915/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6933
# Epoch 916/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 917/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6941
# Epoch 918/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6933
# Epoch 919/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6933
# Epoch 920/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6941
# Epoch 921/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 922/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6933
# Epoch 923/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6941
# Epoch 924/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 925/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6941
# Epoch 926/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6940
# Epoch 927/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6933
# Epoch 928/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6933
# Epoch 929/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6941
# Epoch 930/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 931/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6940
# Epoch 932/1000
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6933
# Epoch 933/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 934/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 935/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6942
# Epoch 936/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6933
# Epoch 937/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6933
# Epoch 938/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 939/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6933
# Epoch 940/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6933
# Epoch 941/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6943
# Epoch 942/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6941
# Epoch 943/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 944/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6933
# Epoch 945/1000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6933
# Epoch 946/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 947/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6942
# Epoch 948/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6941
# Epoch 949/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6940
# Epoch 950/1000
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6933
# Epoch 951/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 952/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6940
# Epoch 953/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 954/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 955/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6941
# Epoch 956/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6933
# Epoch 957/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6933
# Epoch 958/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 959/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 960/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6933
# Epoch 961/1000
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6943
# Epoch 962/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6933
# Epoch 963/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 964/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6942
# Epoch 965/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 966/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6933
# Epoch 967/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6942
# Epoch 968/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6940
# Epoch 969/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 970/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6940
# Epoch 971/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6939
# Epoch 972/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6939
# Epoch 973/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6933
# Epoch 974/1000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6933
# Epoch 975/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6940
# Epoch 976/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 977/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6933
# Epoch 978/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6940
# Epoch 979/1000
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6939
# Epoch 980/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 981/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 982/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6940
# Epoch 983/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6933
# Epoch 984/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6933
# Epoch 985/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6940
# Epoch 986/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6933
# Epoch 987/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6933
# Epoch 988/1000
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6933
# Epoch 989/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6941
# Epoch 990/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6940
# Epoch 991/1000
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6932
# Epoch 992/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6933
# Epoch 993/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6940
# Epoch 994/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6939
# Epoch 995/1000
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6932
# Epoch 996/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6932
# Epoch 997/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6940
# Epoch 998/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6932
# Epoch 999/1000
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6932
# Epoch 1000/1000
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6932
# {'name': 'dense_4', 'trainable': True, 'dtype': 'float32', 'batch_input_shape': (None, 2), 'units': 2, 'activation': 'sigmoid', 'use_bias': True, 'kernel_initializer': {'module': 'keras.initializers', 'class_name': 'GlorotUniform', 'config': {'seed': None}, 'registered_name': None}, 'bias_initializer': {'module': 'keras.initializers', 'class_name': 'Zeros', 'config': {}, 'registered_name': None}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None} [array([[-0.8813468 , -0.08908261],
#        [-0.311592  ,  0.48426148]], dtype=float32), array([-0.33742934, -0.3125602 ], dtype=float32)]
# 226/226 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 28ms/step
# 489/489 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 75ms/step
